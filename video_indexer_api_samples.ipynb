# %% [markdown]
# ### Video Indexer API Samples (Python)

# %% [markdown]
# This notebook provides samples for the following operations in Video Indexer:
#
# (1) Get account details.
# (2) Upload a video from URL.
# (2A) Upload a video from local file.
# (3) Wait for the video to finish indexing.
# (4) Search for video and get insights.
# (5) Use the Widgets API.
#
# Make sure you're logged-in with `az` to authenticate your account.
#
# Copy the `.env.example` file to a new file named `.env`, and update the values with your own account settings.

# %%
# imports
#from dotenv import dotenv_values
from pprint import pprint

from VideoIndexerClient.Consts import Consts
from VideoIndexerClient.VideoIndexerClient import VideoIndexerClient

# %% [markdown]
# Define the following parameters based on your account settings, in case they are different or not defined as environment variables:

# %%
#config = dotenv_values(".env")

AccountName = 'demo-aivideindexer'
ResourceGroup = 'demo-res'
SubscriptionId = '113b1fed-e329-464a-a730-82128f02030d'

ApiVersion = '2024-01-01'
ApiEndpoint = 'https://api.videoindexer.ai'
AzureResourceManager = 'https://management.azure.com'

# create and validate consts
consts = Consts(ApiVersion, ApiEndpoint, AzureResourceManager, AccountName, ResourceGroup, SubscriptionId)

# %%
# Authenticate

# create Video Indexer Client
client = VideoIndexerClient()

# Get access tokens (arm and Video Indexer account)
client.authenticate_async(consts)

# %% [markdown]
# #### Sample 1 - Get Account Basic Details
# Get account details, not required in most cases.

# %%
client.get_account_async()
# Out:
# [Account Details] Id:f9e62e90-4040-4f12-aebd-1c3b703fc2b2, Location: eastus

# %% [markdown]
# #### Sample 2 - Index a Video from URL
# Upload a video from URL, do not wait for the index operation to complete.
# Define `videoUrl` and `ExcludedAI` first.
# `ExcludedAI` - A list of the AIs you would like to exclude in the format `['Faces', 'Labels', 'Emotions','ObservedPeople']`. Leave empty if you do not want to exclude any AIs. For more details see [here](https://api-portal.videoindexer.ai/api-details#api=Operations&operation=Upload-Video:~:text=AI%20to%20exclude%20when%20indexing%2C%20for%20example%20for%20sensitive%20scenarios.%20Options%20are%3A%20Face/Observed%20peopleEmotions/Labels%7D).

# %%
VideoUrl = 'https://demoacostastorage.blob.core.windows.net/files/molotov_interview.mp4'
ExcludedAI = []

video_id = client.upload_url_async('my-video-name', VideoUrl, ExcludedAI, False)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 VideoUrl = 'https://demoacostastorage.blob.core.windows.net/files/molotov_interview.mp4'
#       2 ExcludedAI = []
# ----> 4 video_id = client.upload_url_async('my-video-name', VideoUrl, ExcludedAI, False)
#
# File c:\Users\angelgabriel\Documents\casystems_empresa\proyects\video_indexer\azure-video-indexer-samples\API-Samples\Python\VideoIndexerClient\VideoIndexerClient.py:90, in VideoIndexerClient.upload_url_async(self, video_name, video_url, excluded_ai, wait_for_index, video_description, privacy)
#      86     params['excludedAI'] = ','.join(excluded_ai)
#      88 response = requests.post(url, params=params)
# ---> 90 response.raise_for_status()
#      92 video_id = response.json().get('id')
#      93 print(f'Video ID {video_id} was uploaded successfully')
#
# File c:\Python312\Lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1019     http_error_msg = (
#    1020         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1021     )
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 409 Client Error: Conflict for url: https://api.videoindexer.ai/eastus/Accounts/f9e62e90-4040-4f12-aebd-1c3b703fc2b2/Videos?accessToken=eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.....FkGU1b8RG-y7FuuvMPsFGSt03J35XtFc8itM2DrVDQ6ExqfN0Tb2dxCkT-UDZxp1rEZM760SVbhnBAXHBW5JMYUoioR2UwhXF7IVVwI0pA8JgbhYzOCYfWg0sxj6syR3wkyUSUgCWoOch9K6GSmt2gYzo7XMQ8HYwknkr_HeFVxpe312cJR-fwpEbIOA48Q65O8ArDH9aGeRrFRPI_NU1fRHVnV1mNyWjvMYCnPiDgtGitG7NW-mUZjpOWGPhkFNwwrI29GQ63LP13WUeo17Yh4BT6VNx8TP2zrPU4SLbnHFLkfk7gcqFzuGeDmeq5lD8cN_dHNNTfvyuYXad3VI_w&name=my-video-name&description=&privacy=private&videoUrl=https%3A%2F%2Fdemoacostastorage.blob.core.windows.net%2Ffiles%2Fmolotov_interview.mp4

# %% [markdown]
# #### Sample 2A - Index a Video From File
# Upload From Local File.
# Define `LocalVideoPath` first.

# %%
LocalVideoPath = 'YOUR_LOCAL_VIDEO_FILE_PATH'

file_video_id = client.file_upload_async(LocalVideoPath, video_name=None, excluded_ai=ExcludedAI)

# %% [markdown]
# #### Sample 3 - Polling on Video Completion Event
# Wait for the video index to finish (Polling method).

# %%
client.wait_for_index_async(file_video_id)

# %%
client.wait_for_index_async(video_id)
# Out:
# Checking if video bca891963e has finished indexing...
# The video index has completed. Here is the full JSON of the index for video ID bca891963e:
# {'partition': None, 'description': None, 'privacyMode': 'Private', 'state': 'Processed', 'accountId': 'f9e62e90-4040-4f12-aebd-1c3b703fc2b2', 'id': 'bca891963e', 'name': 'my-video-name', 'userName': 'Ángel Gabriel Larios Acosta', 'created': '2024-06-05T18:43:25.2333333+00:00', 'isOwned': True, 'isEditable': True, 'isBase': True, 'durationInSeconds': 59, 'duration': '0:00:59.814603', 'summarizedInsights': {'name': 'my-video-name', 'id': 'bca891963e', 'privacyMode': 'Private', 'duration': {'time': '0:00:59.814603', 'seconds': 59.8}, 'thumbnailVideoId': 'bca891963e', 'thumbnailId': '395f3aa4-c185-4ce1-8568-7730f9c120c2', 'faces': [{'videoId': 'bca891963e', 'confidence': 0, 'description': None, 'title': None, 'thumbnailId': '969f87ca-c3ba-4225-85dd-16b9c9daf289', 'seenDuration': 59.8, 'seenDurationRatio': 0.9998, 'id': 1031, 'name': 'Unknown #1', 'appearances': [{'startTime': '0:00:00', 'endTime': '0:00:59.8', 'startSeconds': 0, 'endSeconds': 59.8}]}, {'videoId': 'bca891963e', 'confidence': 0, 'description': None, 'title': None, 'thumbnailId': '6907e664-7fb9-483a-997e-a693924df79a', 'seenDuration': 0.7, 'seenDurationRatio': 0.0117, 'id': 1011, 'name': 'Unknown #2', 'appearances': [{'startTime': '0:00:04.7', 'endTime': '0:00:05.4', 'startSeconds': 4.7, 'endSeconds': 5.4}]}], 'keywords': [], 'sentiments': [{'sentimentKey': 'Neutral', 'seenDurationRatio': 0.9998, 'appearances': [{'startTime': '0:00:00', 'endTime': '0:00:59.814603', 'startSeconds': 0, 'endSeconds': 59.8}]}], 'emotions': [], 'audioEffects': [], 'labels': [{'id': 2, 'name': 'human face', 'appearances': [{'confidence': 0.9933, 'startTime': '0:00:00', 'endTime': '0:00:59.0333333', 'startSeconds': 0, 'endSeconds': 59}]}, {'id': 3, 'name': 'clothing', 'appearances': [{'confidence': 0.9897, 'startTime': '0:00:00', 'endTime': '0:00:59.0333333', 'startSeconds': 0, 'endSeconds': 59}]}, {'id': 4, 'name': 'person', 'appearances': [{'confidence': 0.9882, 'startTime': '0:00:00', 'endTime': '0:00:59.0333333', 'startSeconds': 0, 'endSeconds': 59}]}, {'id': 1, 'name': 'text', 'appearances': [{'confidence': 0.9805, 'startTime': '0:00:00', 'endTime': '0:00:55.0333333', 'startSeconds': 0, 'endSeconds': 55}]}, {'id': 6, 'name': 'man', 'appearances': [{'confidence': 0.9605, 'startTime': '0:00:10', 'endTime': '0:00:10.0333333', 'startSeconds': 10, 'endSeconds': 10}, {'confidence': 0.9654, 'startTime': '0:00:31', 'endTime': '0:00:31.0333333', 'startSeconds': 31, 'endSeconds': 31}, {'confidence': 0.955, 'startTime': '0:00:54', 'endTime': '0:00:58.0333333', 'startSeconds': 54, 'endSeconds': 58}]}, {'id': 5, 'name': 'smile', 'appearances': [{'confidence': 0.9713, 'startTime': '0:00:10', 'endTime': '0:00:10.0333333', 'startSeconds': 10, 'endSeconds': 10}, {'confidence': 0.9717, 'startTime': '0:00:57', 'endTime': '0:00:59.0333333', 'startSeconds': 57, 'endSeconds': 59}]}, {'id': 7, 'name': 't-shirt', 'appearances': [{'confidence': 0.9535, 'startTime': '0:00:19', 'endTime': '0:00:19.0333333', 'startSeconds': 19, 'endSeconds': 19}, {'confidence': 0.953, 'startTime': '0:00:30', 'endTime': '0:00:30.0333333', 'startSeconds': 30, 'endSeconds': 30}]}], 'framePatterns': [], 'brands': [], 'namedLocations': [{'referenceId': 'Camp_Nou', 'referenceUrl': 'https://en.wikipedia.org/wiki/Camp_Nou', 'confidence': 0.84, 'description': "Camp Nou ([ˌkamˈnɔw], meaning new field, often referred to in English as the Nou Camp) is the home stadium of FC Barcelona since its completion in 1957. With a seating capacity of 99,354, it is the largest stadium in Spain and Europe, and the third largest football stadium in the world in capacity. It has hosted two European Cup/Champions League finals in 1989 and 1999, two UEFA Cup Winners' Cup finals, four Inter-Cities Fairs Cup final games, five UEFA Super Cup final games, four Copa del Rey finals, two Copa de la Liga final games, twenty-one Supercopa de España final games, five matches including the opening game of the 1982 FIFA World Cup, two out of four matches at the 1964 Eur ...

# %% [markdown]
# #### Sample 4 - Get the Video insights
# Get the video insights.

# %%
insights = client.get_video_async(file_video_id)
pprint(insights)

# %%
insights = client.get_video_async(video_id)
pprint(insights)
# Out:
# Searching videos in account f9e62e90-4040-4f12-aebd-1c3b703fc2b2 for video ID bca891963e.
# Here are the search results:
# {'partition': None, 'description': None, 'privacyMode': 'Private', 'state': 'Processed', 'accountId': 'f9e62e90-4040-4f12-aebd-1c3b703fc2b2', 'id': 'bca891963e', 'name': 'my-video-name', 'userName': 'Ángel Gabriel Larios Acosta', 'created': '2024-06-05T18:43:25.2333333+00:00', 'isOwned': True, 'isEditable': True, 'isBase': True, 'durationInSeconds': 59, 'duration': '0:00:59.814603', 'summarizedInsights': {'name': 'my-video-name', 'id': 'bca891963e', 'privacyMode': 'Private', 'duration': {'time': '0:00:59.814603', 'seconds': 59.8}, 'thumbnailVideoId': 'bca891963e', 'thumbnailId': '395f3aa4-c185-4ce1-8568-7730f9c120c2', 'faces': [{'videoId': 'bca891963e', 'confidence': 0, 'description': None, 'title': None, 'thumbnailId': '969f87ca-c3ba-4225-85dd-16b9c9daf289', 'seenDuration': 59.8, 'seenDurationRatio': 0.9998, 'id': 1031, 'name': 'Unknown #1', 'appearances': [{'startTime': '0:00:00', 'endTime': '0:00:59.8', 'startSeconds': 0, 'endSeconds': 59.8}]}, {'videoId': 'bca891963e', 'confidence': 0, 'description': None, 'title': None, 'thumbnailId': '6907e664-7fb9-483a-997e-a693924df79a', 'seenDuration': 0.7, 'seenDurationRatio': 0.0117, 'id': 1011, 'name': 'Unknown #2', 'appearances': [{'startTime': '0:00:04.7', 'endTime': '0:00:05.4', 'startSeconds': 4.7, 'endSeconds': 5.4}]}], 'keywords': [], 'sentiments': [{'sentimentKey': 'Neutral', 'seenDurationRatio': 0.9998, 'appearances': [{'startTime': '0:00:00', 'endTime': '0:00:59.814603', 'startSeconds': 0, 'endSeconds': 59.8}]}], 'emotions': [], 'audioEffects': [], 'labels': [{'id': 2, 'name': 'human face', 'appearances': [{'confidence': 0.9933, 'startTime': '0:00:00', 'endTime': '0:00:59.0333333', 'startSeconds': 0, 'endSeconds': 59}]}, {'id': 3, 'name': 'clothing', 'appearances': [{'confidence': 0.9897, 'startTime': '0:00:00', 'endTime': '0:00:59.0333333', 'startSeconds': 0, 'endSeconds': 59}]}, {'id': 4, 'name': 'person', 'appearances': [{'confidence': 0.9882, 'startTime': '0:00:00', 'endTime': '0:00:59.0333333', 'startSeconds': 0, 'endSeconds': 59}]}, {'id': 1, 'name': 'text', 'appearances': [{'confidence': 0.9805, 'startTime': '0:00:00', 'endTime': '0:00:55.0333333', 'startSeconds': 0, 'endSeconds': 55}]}, {'id': 6, 'name': 'man', 'appearances': [{'confidence': 0.9605, 'startTime': '0:00:10', 'endTime': '0:00:10.0333333', 'startSeconds': 10, 'endSeconds': 10}, {'confidence': 0.9654, 'startTime': '0:00:31', 'endTime': '0:00:31.0333333', 'startSeconds': 31, 'endSeconds': 31}, {'confidence': 0.955, 'startTime': '0:00:54', 'endTime': '0:00:58.0333333', 'startSeconds': 54, 'endSeconds': 58}]}, {'id': 5, 'name': 'smile', 'appearances': [{'confidence': 0.9713, 'startTime': '0:00:10', 'endTime': '0:00:10.0333333', 'startSeconds': 10, 'endSeconds': 10}, {'confidence': 0.9717, 'startTime': '0:00:57', 'endTime': '0:00:59.0333333', 'startSeconds': 57, 'endSeconds': 59}]}, {'id': 7, 'name': 't-shirt', 'appearances': [{'confidence': 0.9535, 'startTime': '0:00:19', 'endTime': '0:00:19.0333333', 'startSeconds': 19, 'endSeconds': 19}, {'confidence': 0.953, 'startTime': '0:00:30', 'endTime': '0:00:30.0333333', 'startSeconds': 30, 'endSeconds': 30}]}], 'framePatterns': [], 'brands': [], 'namedLocations': [{'referenceId': 'Camp_Nou', 'referenceUrl': 'https://en.wikipedia.org/wiki/Camp_Nou', 'confidence': 0.84, 'description': "Camp Nou ([ˌkamˈnɔw], meaning new field, often referred to in English as the Nou Camp) is the home stadium of FC Barcelona since its completion in 1957. With a seating capacity of 99,354, it is the largest stadium in Spain and Europe, and the third largest football stadium in the world in capacity. It has hosted two European Cup/Champions League finals in 1989 and 1999, two UEFA Cup Winners' Cup finals, four Inter-Cities Fairs Cup final games, five UEFA Super Cup final games, four Copa del Rey finals, two Copa de la Liga final games, twenty-one Supercopa de España final games, five matches including the opening game of the 1982 FIFA World Cup, two out of four matches at the 1964 Eur ...
# {'accountId': 'f9e62e90-4040-4f12-aebd-1c3b703fc2b2',
#  'created': '2024-06-05T18:43:25.2333333+00:00',
#  'description': None,
#  'duration': '0:00:59.814603',
#  'durationInSeconds': 59,
#  'id': 'bca891963e',
#  'isBase': True,
#  'isEditable': True,
#  'isOwned': True,
#  'name': 'my-video-name',
#  'partition': None,
#  'privacyMode': 'Private',
#  'state': 'Processed',
#  'summarizedInsights': {'audioEffects': [],
#                         'brands': [],
#                         'duration': {'seconds': 59.8, 'time': '0:00:59.814603'},
#                         'emotions': [],
#                         'faces': [{'appearances': [{'endSeconds': 59.8,
#                                                     'endTime': '0:00:59.8',
#                                                     'startSeconds': 0,
#                                                     'startTime': '0:00:00'}],
#                                    'confidence': 0,
#                                    'description': None,
#                                    'id': 1031,
#                                    'name': 'Unknown #1',
#                                    'seenDuration': 59.8,
#                                    'seenDurationRatio': 0.9998,
#                                    'thumbnailId': '969f87ca-c3ba-4225-85dd-16b9c9daf289',
#                                    'title': None,
#                                    'videoId': 'bca891963e'},
#                                   {'appearances': [{'endSeconds': 5.4,
#                                                     'endTime': '0:00:05.4',
#                                                     'startSeconds': 4.7,
#                                                     'startTime': '0:00:04.7'}],
#                                    'confidence': 0,
#                                    'description': None,
#                                    'id': 1011,
#                                    'name': 'Unknown #2',
#                                    'seenDuration': 0.7,
#                                    'seenDurationRatio': 0.0117,
#                                    'thumbnailId': '6907e664-7fb9-483a-997e-a693924df79a',
#                                    'title': None,
#                                    'videoId': 'bca891963e'}],
#                         'framePatterns': [],
#                         'id': 'bca891963e',
#                         'keywords': [],
#                         'labels': [{'appearances': [{'confidence': 0.9933,
#                                                      'endSeconds': 59,
#                                                      'endTime': '0:00:59.0333333',
#                                                      'startSeconds': 0,
#                                                      'startTime': '0:00:00'}],
#                                     'id': 2,
#                                     'name': 'human face'},
#                                    {'appearances': [{'confidence': 0.9897,
#                                                      'endSeconds': 59,
#                                                      'endTime': '0:00:59.0333333',
#                                                      'startSeconds': 0,
#                                                      'startTime': '0:00:00'}],
#                                     'id': 3,
#                                     'name': 'clothing'},
#                                    {'appearances': [{'confidence': 0.9882,
#                                                      'endSeconds': 59,
#                                                      'endTime': '0:00:59.0333333',
#                                                      'startSeconds': 0,
#                                                      'startTime': '0:00:00'}],
#                                     'id': 4,
#                                     'name': 'person'},
#                                    {'appearances': [{'confidence': 0.9805,
#                                                      'endSeconds': 55,
#                                                      'endTime': '0:00:55.0333333',
#                                                      'startSeconds': 0,
#                                                      'startTime': '0:00:00'}],
#                                     'id': 1,
#                                     'name': 'text'},
#                                    {'appearances': [{'confidence': 0.9605,
#                                                      'endSeconds': 10,
#                                                      'endTime': '0:00:10.0333333',
#                                                      'startSeconds': 10,
#                                                      'startTime': '0:00:10'},
#                                                     {'confidence': 0.9654,
#                                                      'endSeconds': 31,
#                                                      'endTime': '0:00:31.0333333',
#                                                      'startSeconds': 31,
#                                                      'startTime': '0:00:31'},
#                                                     {'confidence': 0.955,
#                                                      'endSeconds': 58,
#                                                      'endTime': '0:00:58.0333333',
#                                                      'startSeconds': 54,
#                                                      'startTime': '0:00:54'}],
#                                     'id': 6,
#                                     'name': 'man'},
#                                    {'appearances': [{'confidence': 0.9713,
#                                                      'endSeconds': 10,
#                                                      'endTime': '0:00:10.0333333',
#                                                      'startSeconds': 10,
#                                                      'startTime': '0:00:10'},
#                                                     {'confidence': 0.9717,
#                                                      'endSeconds': 59,
#                                                      'endTime': '0:00:59.0333333',
#                                                      'startSeconds': 57,
#                                                      'startTime': '0:00:57'}],
#                                     'id': 5,
#                                     'name': 'smile'},
#                                    {'appearances': [{'confidence': 0.9535,
#                                                      'endSeconds': 19,
#                                                      'endTime': '0:00:19.0333333',
#                                                      'startSeconds': 19,
#                                                      'startTime': '0:00:19'},
#                                                     {'confidence': 0.953,
#                                                      'endSeconds': 30,
#                                                      'endTime': '0:00:30.0333333',
#                                                      'startSeconds': 30,
#                                                      'startTime': '0:00:30'}],
#                                     'id': 7,
#                                     'name': 't-shirt'}],
#                         'name': 'my-video-name',
#                         'namedLocations': [{'appearances': [{'endSeconds': 42,
#                                                              'endTime': '0:00:42.0333333',
#                                                              'startSeconds': 42,
#                                                              'startTime': '0:00:42'}],
#                                             'confidence': 0.84,
#                                             'description': 'Camp Nou '
#                                                            '([ˌkamˈnɔw], '
#                                                            'meaning new field, '
#                                                            'often referred to '
#                                                            'in English as the '
#                                                            'Nou Camp) is the '
#                                                            'home stadium of FC '
#                                                            'Barcelona since '
#                                                            'its completion in '
#                                                            '1957. With a '
#                                                            'seating capacity '
#                                                            'of 99,354, it is '
#                                                            'the largest '
#                                                            'stadium in Spain '
#                                                            'and Europe, and '
#                                                            'the third largest '
#                                                            'football stadium '
#                                                            'in the world in '
#                                                            'capacity. It has '
#                                                            'hosted two '
#                                                            'European '
#                                                            'Cup/Champions '
#                                                            'League finals in '
#                                                            '1989 and 1999, two '
#                                                            "UEFA Cup Winners' "
#                                                            'Cup finals, four '
#                                                            'Inter-Cities Fairs '
#                                                            'Cup final games, '
#                                                            'five UEFA Super '
#                                                            'Cup final games, '
#                                                            'four Copa del Rey '
#                                                            'finals, two Copa '
#                                                            'de la Liga final '
#                                                            'games, twenty-one '
#                                                            'Supercopa de '
#                                                            'España final '
#                                                            'games, five '
#                                                            'matches including '
#                                                            'the opening game '
#                                                            'of the 1982 FIFA '
#                                                            'World Cup, two out '
#                                                            'of four matches at '
#                                                            'the 1964 European '
#                                                            "Nations' Cup and "
#                                                            'the football '
#                                                            'competition final '
#                                                            'at the 1992 Summer '
#                                                            'Olympics.',
#                                             'id': 1,
#                                             'name': 'Camp Nou',
#                                             'referenceId': 'Camp_Nou',
#                                             'referenceUrl': 'https://en.wikipedia.org/wiki/Camp_Nou',
#                                             'seenDuration': 0}],
#                         'namedPeople': [],
#                         'privacyMode': 'Private',
#                         'sentiments': [{'appearances': [{'endSeconds': 59.8,
#                                                          'endTime': '0:00:59.814603',
#                                                          'startSeconds': 0,
#                                                          'startTime': '0:00:00'}],
#                                         'seenDurationRatio': 0.9998,
#                                         'sentimentKey': 'Neutral'}],
#                         'statistics': {'correspondenceCount': 1,
#                                        'speakerLongestMonolog': {'1': 0,
#                                                                  '2': 0},
#                                        'speakerNumberOfFragments': {'1': 1,
#                                                                     '2': 1},
#                                        'speakerTalkToListenRatio': {'1': 0.5,
#                                                                     '2': 0.5},
#                                        'speakerWordCount': {'1': 1, '2': 1}},
#                         'thumbnailId': '395f3aa4-c185-4ce1-8568-7730f9c120c2',
#                         'thumbnailVideoId': 'bca891963e',
#                         'topics': [{'appearances': [{'endSeconds': 33.7,
#                                                      'endTime': '0:00:33.68',
#                                                      'startSeconds': 2,
#                                                      'startTime': '0:00:01.96'}],
#                                     'confidence': 0.5213,
#                                     'iabName': 'Education',
#                                     'id': 1,
#                                     'iptcName': 'science and technology',
#                                     'name': 'Education/Technology',
#                                     'referenceUrl': None}]},
#  'userName': 'Ángel Gabriel Larios Acosta',
#  'videos': [{'accountId': 'f9e62e90-4040-4f12-aebd-1c3b703fc2b2',
#              'detectSourceLanguage': False,
#              'excludedAIs': [],
#              'externalId': None,
#              'externalUrl': None,
#              'failureMessage': '',
#              'height': 1280,
#              'id': 'bca891963e',
#              'indexingPreset': 'Default',
#              'insights': {'blocks': [{'id': 0,
#                                       'instances': [{'adjustedEnd': '0:00:59.814603',
#                                                      'adjustedStart': '0:00:00',
#                                                      'end': '0:00:59.814603',
#                                                      'start': '0:00:00'}]}],
#                           'detectedObjects': [{'displayName': 'necktie',
#                                                'id': 1,
#                                                'instances': [{'adjustedEnd': '0:00:11.4',
#                                                               'adjustedStart': '0:00:10.433333',
#                                                               'confidence': 0.644,
#                                                               'end': '0:00:11.4',
#                                                               'start': '0:00:10.433333'},
#                                                              {'adjustedEnd': '0:00:36.766667',
#                                                               'adjustedStart': '0:00:36.4',
#                                                               'confidence': 0.617,
#                                                               'end': '0:00:36.766667',
#                                                               'start': '0:00:36.4'},
#                                                              {'adjustedEnd': '0:00:49.433333',
#                                                               'adjustedStart': '0:00:49.233333',
#                                                               'confidence': 0.537,
#                                                               'end': '0:00:49.433333',
#                                                               'start': '0:00:49.233333'}],
#                                                'thumbnailId': 'a5f6b088-7c95-4176-a316-5eb741d8b4e1',
#                                                'type': 'Necktie',
#                                                'wikiDataId': 'Q44416'},
#                                               {'displayName': 'necktie',
#                                                'id': 2,
#                                                'instances': [{'adjustedEnd': '0:00:55.4',
#                                                               'adjustedStart': '0:00:55.033333',
#                                                               'confidence': 0.693,
#                                                               'end': '0:00:55.4',
#                                                               'start': '0:00:55.033333'}],
#                                                'thumbnailId': '718f9432-cfcd-443a-950f-70d53e0d1f33',
#                                                'type': 'Necktie',
#                                                'wikiDataId': 'Q44416'}],
#                           'duration': '0:00:59.814603',
#                           'faces': [{'confidence': 0,
#                                      'description': None,
#                                      'highQuality': True,
#                                      'id': 1031,
#                                      'imageUrl': None,
#                                      'instances': [{'adjustedEnd': '0:00:02.2666667',
#                                                     'adjustedStart': '0:00:00',
#                                                     'end': '0:00:02.2666667',
#                                                     'start': '0:00:00',
#                                                     'thumbnailsIds': ['bf9ac159-c70d-4401-840e-c02416ea0625']},
#                                                    {'adjustedEnd': '0:00:04.7',
#                                                     'adjustedStart': '0:00:02.5333333',
#                                                     'end': '0:00:04.7',
#                                                     'start': '0:00:02.5333333'},
#                                                    {'adjustedEnd': '0:00:59.8',
#                                                     'adjustedStart': '0:00:05.4',
#                                                     'end': '0:00:59.8',
#                                                     'start': '0:00:05.4',
#                                                     'thumbnailsIds': ['a8fbad39-9399-4334-bace-a3cdb4301b70',
#                                                                       'aee4f91e-4ad9-4e69-b471-25db718aeb52',
#                                                                       '4f35f205-1fb8-48c6-8499-8ed2c996f305',
#                                                                       '769d6a45-1aef-4b64-8dd6-7928d0b037ab',
#                                                                       '6dada084-a062-42ec-8820-748c77ca72f9',
#                                                                       'fff4523a-f092-4c90-b42b-c53c551cf030',
#                                                                       '575faa80-7fe0-4b9b-8f63-8dbbdfea57a3',
#                                                                       '2caba5fe-adb8-42b5-aaf3-1be77a15e083',
#                                                                       'fbab85ce-108c-4191-9da6-7e7141802213',
#                                                                       'a211c0fb-8d9a-46da-aba9-55d931dd1c5b',
#                                                                       'acb10eef-c739-4232-98f5-67757d7c6927']}],
#                                      'name': 'Unknown #1',
#                                      'thumbnailId': '969f87ca-c3ba-4225-85dd-16b9c9daf289',
#                                      'thumbnails': [{'fileName': 'FaceInstanceThumbnail_bf9ac159-c70d-4401-840e-c02416ea0625.jpg',
#                                                      'id': 'bf9ac159-c70d-4401-840e-c02416ea0625',
#                                                      'instances': [{'adjustedEnd': '0:00:00.0333333',
#                                                                     'adjustedStart': '0:00:00',
#                                                                     'end': '0:00:00.0333333',
#                                                                     'start': '0:00:00'}]},
#                                                     {'fileName': 'FaceInstanceThumbnail_575faa80-7fe0-4b9b-8f63-8dbbdfea57a3.jpg',
#                                                      'id': '575faa80-7fe0-4b9b-8f63-8dbbdfea57a3',
#                                                      'instances': [{'adjustedEnd': '0:00:10.2999999',
#                                                                     'adjustedStart': '0:00:10.2666666',
#                                                                     'end': '0:00:10.2999999',
#                                                                     'start': '0:00:10.2666666'}]},
#                                                     {'fileName': 'FaceInstanceThumbnail_4f35f205-1fb8-48c6-8499-8ed2c996f305.jpg',
#                                                      'id': '4f35f205-1fb8-48c6-8499-8ed2c996f305',
#                                                      'instances': [{'adjustedEnd': '0:00:14.0333333',
#                                                                     'adjustedStart': '0:00:14',
#                                                                     'end': '0:00:14.0333333',
#                                                                     'start': '0:00:14'}]},
#                                                     {'fileName': 'FaceInstanceThumbnail_a8fbad39-9399-4334-bace-a3cdb4301b70.jpg',
#                                                      'id': 'a8fbad39-9399-4334-bace-a3cdb4301b70',
#                                                      'instances': [{'adjustedEnd': '0:00:15.4333333',
#                                                                     'adjustedStart': '0:00:15.4',
#                                                                     'end': '0:00:15.4333333',
#                                                                     'start': '0:00:15.4'}]},
#                                                     {'fileName': 'FaceInstanceThumbnail_6dada084-a062-42ec-8820-748c77ca72f9.jpg',
#                                                      'id': '6dada084-a062-42ec-8820-748c77ca72f9',
#                                                      'instances': [{'adjustedEnd': '0:00:20.5666666',
#                                                                     'adjustedStart': '0:00:20.5333333',
#                                                                     'end': '0:00:20.5666666',
#                                                                     'start': '0:00:20.5333333'}]},
#                                                     {'fileName': 'FaceInstanceThumbnail_aee4f91e-4ad9-4e69-b471-25db718aeb52.jpg',
#                                                      'id': 'aee4f91e-4ad9-4e69-b471-25db718aeb52',
#                                                      'instances': [{'adjustedEnd': '0:00:25.6999999',
#                                                                     'adjustedStart': '0:00:25.6666666',
#                                                                     'end': '0:00:25.6999999',
#                                                                     'start': '0:00:25.6666666'}]},
#                                                     {'fileName': 'FaceInstanceThumbnail_fff4523a-f092-4c90-b42b-c53c551cf030.jpg',
#                                                      'id': 'fff4523a-f092-4c90-b42b-c53c551cf030',
#                                                      'instances': [{'adjustedEnd': '0:00:30.8333333',
#                                                                     'adjustedStart': '0:00:30.8',
#                                                                     'end': '0:00:30.8333333',
#                                                                     'start': '0:00:30.8'}]},
#                                                     {'fileName': 'FaceInstanceThumbnail_fbab85ce-108c-4191-9da6-7e7141802213.jpg',
#                                                      'id': 'fbab85ce-108c-4191-9da6-7e7141802213',
#                                                      'instances': [{'adjustedEnd': '0:00:35.9666666',
#                                                                     'adjustedStart': '0:00:35.9333333',
#                                                                     'end': '0:00:35.9666666',
#                                                                     'start': '0:00:35.9333333'}]},
#                                                     {'fileName': 'FaceInstanceThumbnail_a211c0fb-8d9a-46da-aba9-55d931dd1c5b.jpg',
#                                                      'id': 'a211c0fb-8d9a-46da-aba9-55d931dd1c5b',
#                                                      'instances': [{'adjustedEnd': '0:00:41.0999999',
#                                                                     'adjustedStart': '0:00:41.0666666',
#                                                                     'end': '0:00:41.0999999',
#                                                                     'start': '0:00:41.0666666'}]},
#                                                     {'fileName': 'FaceInstanceThumbnail_2caba5fe-adb8-42b5-aaf3-1be77a15e083.jpg',
#                                                      'id': '2caba5fe-adb8-42b5-aaf3-1be77a15e083',
#                                                      'instances': [{'adjustedEnd': '0:00:46.2333333',
#                                                                     'adjustedStart': '0:00:46.2',
#                                                                     'end': '0:00:46.2333333',
#                                                                     'start': '0:00:46.2'}]},
#                                                     {'fileName': 'FaceInstanceThumbnail_769d6a45-1aef-4b64-8dd6-7928d0b037ab.jpg',
#                                                      'id': '769d6a45-1aef-4b64-8dd6-7928d0b037ab',
#                                                      'instances': [{'adjustedEnd': '0:00:51.3666666',
#                                                                     'adjustedStart': '0:00:51.3333333',
#                                                                     'end': '0:00:51.3666666',
#                                                                     'start': '0:00:51.3333333'}]},
#                                                     {'fileName': 'FaceInstanceThumbnail_acb10eef-c739-4232-98f5-67757d7c6927.jpg',
#                                                      'id': 'acb10eef-c739-4232-98f5-67757d7c6927',
#                                                      'instances': [{'adjustedEnd': '0:00:56.4999999',
#                                                                     'adjustedStart': '0:00:56.4666666',
#                                                                     'end': '0:00:56.4999999',
#                                                                     'start': '0:00:56.4666666'}]}],
#                                      'title': None},
#                                     {'confidence': 0,
#                                      'description': None,
#                                      'highQuality': True,
#                                      'id': 1011,
#                                      'imageUrl': None,
#                                      'instances': [{'adjustedEnd': '0:00:05.4',
#                                                     'adjustedStart': '0:00:04.7',
#                                                     'end': '0:00:05.4',
#                                                     'start': '0:00:04.7',
#                                                     'thumbnailsIds': ['fe9b802b-f78c-44d5-8d16-d366a9cdfc5d']}],
#                                      'name': 'Unknown #2',
#                                      'thumbnailId': '6907e664-7fb9-483a-997e-a693924df79a',
#                                      'thumbnails': [{'fileName': 'FaceInstanceThumbnail_fe9b802b-f78c-44d5-8d16-d366a9cdfc5d.jpg',
#                                                      'id': 'fe9b802b-f78c-44d5-8d16-d366a9cdfc5d',
#                                                      'instances': [{'adjustedEnd': '0:00:05.1666666',
#                                                                     'adjustedStart': '0:00:05.1333333',
#                                                                     'end': '0:00:05.1666666',
#                                                                     'start': '0:00:05.1333333'}]}],
#                                      'title': None}],
#                           'labels': [{'id': 1,
#                                       'instances': [{'adjustedEnd': '0:00:09.0333333',
#                                                      'adjustedStart': '0:00:00',
#                                                      'confidence': 0.9989,
#                                                      'end': '0:00:09.0333333',
#                                                      'start': '0:00:00'},
#                                                     {'adjustedEnd': '0:00:22.0333333',
#                                                      'adjustedStart': '0:00:11',
#                                                      'confidence': 0.9943,
#                                                      'end': '0:00:22.0333333',
#                                                      'start': '0:00:11'},
#                                                     {'adjustedEnd': '0:00:27.0333333',
#                                                      'adjustedStart': '0:00:24',
#                                                      'confidence': 0.9847,
#                                                      'end': '0:00:27.0333333',
#                                                      'start': '0:00:24'},
#                                                     {'adjustedEnd': '0:00:55.0333333',
#                                                      'adjustedStart': '0:00:29',
#                                                      'confidence': 0.9805,
#                                                      'end': '0:00:55.0333333',
#                                                      'start': '0:00:29'}],
#                                       'language': 'en-US',
#                                       'name': 'text',
#                                       'referenceId': 'communication/writing/text'},
#                                      {'id': 2,
#                                       'instances': [{'adjustedEnd': '0:00:59.0333333',
#                                                      'adjustedStart': '0:00:00',
#                                                      'confidence': 0.9933,
#                                                      'end': '0:00:59.0333333',
#                                                      'start': '0:00:00'}],
#                                       'language': 'en-US',
#                                       'name': 'human face'},
#                                      {'id': 3,
#                                       'instances': [{'adjustedEnd': '0:00:04.0333333',
#                                                      'adjustedStart': '0:00:00',
#                                                      'confidence': 0.9888,
#                                                      'end': '0:00:04.0333333',
#                                                      'start': '0:00:00'},
#                                                     {'adjustedEnd': '0:00:09.0333333',
#                                                      'adjustedStart': '0:00:06',
#                                                      'confidence': 0.9901,
#                                                      'end': '0:00:09.0333333',
#                                                      'start': '0:00:06'},
#                                                     {'adjustedEnd': '0:00:55.0333333',
#                                                      'adjustedStart': '0:00:11',
#                                                      'confidence': 0.9889,
#                                                      'end': '0:00:55.0333333',
#                                                      'start': '0:00:11'},
#                                                     {'adjustedEnd': '0:00:59.0333333',
#                                                      'adjustedStart': '0:00:57',
#                                                      'confidence': 0.9897,
#                                                      'end': '0:00:59.0333333',
#                                                      'start': '0:00:57'}],
#                                       'language': 'en-US',
#                                       'name': 'clothing',
#                                       'referenceId': 'consumer goods/clothing'},
#                                      {'id': 4,
#                                       'instances': [{'adjustedEnd': '0:00:59.0333333',
#                                                      'adjustedStart': '0:00:00',
#                                                      'confidence': 0.9882,
#                                                      'end': '0:00:59.0333333',
#                                                      'start': '0:00:00'}],
#                                       'language': 'en-US',
#                                       'name': 'person',
#                                       'referenceId': 'person'},
#                                      {'id': 5,
#                                       'instances': [{'adjustedEnd': '0:00:10.0333333',
#                                                      'adjustedStart': '0:00:10',
#                                                      'confidence': 0.9713,
#                                                      'end': '0:00:10.0333333',
#                                                      'start': '0:00:10'},
#                                                     {'adjustedEnd': '0:00:59.0333333',
#                                                      'adjustedStart': '0:00:57',
#                                                      'confidence': 0.9717,
#                                                      'end': '0:00:59.0333333',
#                                                      'start': '0:00:57'}],
#                                       'language': 'en-US',
#                                       'name': 'smile'},
#                                      {'id': 6,
#                                       'instances': [{'adjustedEnd': '0:00:10.0333333',
#                                                      'adjustedStart': '0:00:10',
#                                                      'confidence': 0.9605,
#                                                      'end': '0:00:10.0333333',
#                                                      'start': '0:00:10'},
#                                                     {'adjustedEnd': '0:00:31.0333333',
#                                                      'adjustedStart': '0:00:31',
#                                                      'confidence': 0.9654,
#                                                      'end': '0:00:31.0333333',
#                                                      'start': '0:00:31'},
#                                                     {'adjustedEnd': '0:00:56.0333333',
#                                                      'adjustedStart': '0:00:54',
#                                                      'confidence': 0.9726,
#                                                      'end': '0:00:56.0333333',
#                                                      'start': '0:00:54'},
#                                                     {'adjustedEnd': '0:00:58.0333333',
#                                                      'adjustedStart': '0:00:58',
#                                                      'confidence': 0.955,
#                                                      'end': '0:00:58.0333333',
#                                                      'start': '0:00:58'}],
#                                       'language': 'en-US',
#                                       'name': 'man',
#                                       'referenceId': 'person/man'},
#                                      {'id': 7,
#                                       'instances': [{'adjustedEnd': '0:00:19.0333333',
#                                                      'adjustedStart': '0:00:19',
#                                                      'confidence': 0.9535,
#                                                      'end': '0:00:19.0333333',
#                                                      'start': '0:00:19'},
#                                                     {'adjustedEnd': '0:00:30.0333333',
#                                                      'adjustedStart': '0:00:30',
#                                                      'confidence': 0.953,
#                                                      'end': '0:00:30.0333333',
#                                                      'start': '0:00:30'}],
#                                       'language': 'en-US',
#                                       'name': 't-shirt'}],
#                           'language': 'en-US',
#                           'languages': ['en-US'],
#                           'namedLocations': [{'confidence': 0.84,
#                                               'description': 'Camp Nou '
#                                                              '([ˌkamˈnɔw], '
#                                                              'meaning new '
#                                                              'field, often '
#                                                              'referred to in '
#                                                              'English as the '
#                                                              'Nou Camp) is the '
#                                                              'home stadium of '
#                                                              'FC Barcelona '
#                                                              'since its '
#                                                              'completion in '
#                                                              '1957. With a '
#                                                              'seating capacity '
#                                                              'of 99,354, it is '
#                                                              'the largest '
#                                                              'stadium in Spain '
#                                                              'and Europe, and '
#                                                              'the third '
#                                                              'largest football '
#                                                              'stadium in the '
#                                                              'world in '
#                                                              'capacity. It has '
#                                                              'hosted two '
#                                                              'European '
#                                                              'Cup/Champions '
#                                                              'League finals in '
#                                                              '1989 and 1999, '
#                                                              'two UEFA Cup '
#                                                              "Winners' Cup "
#                                                              'finals, four '
#                                                              'Inter-Cities '
#                                                              'Fairs Cup final '
#                                                              'games, five UEFA '
#                                                              'Super Cup final '
#                                                              'games, four Copa '
#                                                              'del Rey finals, '
#                                                              'two Copa de la '
#                                                              'Liga final '
#                                                              'games, '
#                                                              'twenty-one '
#                                                              'Supercopa de '
#                                                              'España final '
#                                                              'games, five '
#                                                              'matches '
#                                                              'including the '
#                                                              'opening game of '
#                                                              'the 1982 FIFA '
#                                                              'World Cup, two '
#                                                              'out of four '
#                                                              'matches at the '
#                                                              '1964 European '
#                                                              "Nations' Cup and "
#                                                              'the football '
#                                                              'competition '
#                                                              'final at the '
#                                                              '1992 Summer '
#                                                              'Olympics.',
#                                               'id': 1,
#                                               'instances': [{'adjustedEnd': '0:00:42.0333333',
#                                                              'adjustedStart': '0:00:42',
#                                                              'end': '0:00:42.0333333',
#                                                              'instanceSource': 'Ocr',
#                                                              'start': '0:00:42'}],
#                                               'isCustom': False,
#                                               'name': 'Camp Nou',
#                                               'referenceId': 'Camp_Nou',
#                                               'referenceUrl': 'https://en.wikipedia.org/wiki/Camp_Nou',
#                                               'tags': []}],
#                           'ocr': [{'angle': 0,
#                                    'confidence': 0.998,
#                                    'height': 22,
#                                    'id': 1,
#                                    'instances': [{'adjustedEnd': '0:00:55.0333333',
#                                                   'adjustedStart': '0:00:00',
#                                                   'end': '0:00:55.0333333',
#                                                   'start': '0:00:00'},
#                                                  {'adjustedEnd': '0:00:59.0333333',
#                                                   'adjustedStart': '0:00:57',
#                                                   'end': '0:00:59.0333333',
#                                                   'start': '0:00:57'}],
#                                    'language': 'en-US',
#                                    'left': 582,
#                                    'text': 'MUNDO',
# ...
#                                                                    'start': '0:00:45.8666667',
#                                                                    'thumbnailId': 'e5d808a9-4be1-427f-9cff-e5266557b1bf'}]},
#                                                    {'id': 43,
#                                                     'instances': [{'adjustedEnd': '0:00:47.0333333',
#                                                                    'adjustedStart': '0:00:47',
#                                                                    'end': '0:00:47.0333333',
#                                                                    'start': '0:00:47',
#                                                                    'thumbnailId': 'a08aef26-c79a-4a98-bf9e-c51cb6e1d48c'}]}],
#                                      'tags': ['ExtremeCloseUp',
#                                               'CenterFace',
#                                               'CloseUp']},
#                                     {'id': 30,
#                                      'instances': [{'adjustedEnd': '0:00:49.5666667',
#                                                     'adjustedStart': '0:00:48.4666667',
#                                                     'end': '0:00:49.5666667',
#                                                     'start': '0:00:48.4666667'}],
#                                      'keyFrames': [{'id': 44,
#                                                     'instances': [{'adjustedEnd': '0:00:48.5666667',
#                                                                    'adjustedStart': '0:00:48.5333333',
#                                                                    'end': '0:00:48.5666667',
#                                                                    'start': '0:00:48.5333333',
#                                                                    'thumbnailId': '7098fd17-c563-438c-8386-f65f5071b957'}]}],
#                                      'tags': ['ExtremeCloseUp', 'CenterFace']},
#                                     {'id': 31,
#                                      'instances': [{'adjustedEnd': '0:00:51.2333333',
#                                                     'adjustedStart': '0:00:49.5666667',
#                                                     'end': '0:00:51.2333333',
#                                                     'start': '0:00:49.5666667'}],
#                                      'keyFrames': [{'id': 45,
#                                                     'instances': [{'adjustedEnd': '0:00:49.8666667',
#                                                                    'adjustedStart': '0:00:49.8333333',
#                                                                    'end': '0:00:49.8666667',
#                                                                    'start': '0:00:49.8333333',
#                                                                    'thumbnailId': '24f2e516-d7b8-469b-8719-47466680c31a'}]}],
#                                      'tags': ['CloseUp', 'CenterFace']},
#                                     {'id': 32,
#                                      'instances': [{'adjustedEnd': '0:00:52.6666667',
#                                                     'adjustedStart': '0:00:51.2333333',
#                                                     'end': '0:00:52.6666667',
#                                                     'start': '0:00:51.2333333'}],
#                                      'keyFrames': [{'id': 46,
#                                                     'instances': [{'adjustedEnd': '0:00:51.3',
#                                                                    'adjustedStart': '0:00:51.2666667',
#                                                                    'end': '0:00:51.3',
#                                                                    'start': '0:00:51.2666667',
#                                                                    'thumbnailId': 'a6f053c8-ae51-4b04-9331-6d1be4efa0db'}]},
#                                                    {'id': 47,
#                                                     'instances': [{'adjustedEnd': '0:00:52.3333333',
#                                                                    'adjustedStart': '0:00:52.3',
#                                                                    'end': '0:00:52.3333333',
#                                                                    'start': '0:00:52.3',
#                                                                    'thumbnailId': 'a7c262d5-4393-4877-bf40-8c02caa41d29'}]}],
#                                      'tags': ['ExtremeCloseUp',
#                                               'CenterFace',
#                                               'CloseUp']},
#                                     {'id': 33,
#                                      'instances': [{'adjustedEnd': '0:00:55.0333333',
#                                                     'adjustedStart': '0:00:52.6666667',
#                                                     'end': '0:00:55.0333333',
#                                                     'start': '0:00:52.6666667'}],
#                                      'keyFrames': [{'id': 48,
#                                                     'instances': [{'adjustedEnd': '0:00:52.7333333',
#                                                                    'adjustedStart': '0:00:52.7',
#                                                                    'end': '0:00:52.7333333',
#                                                                    'start': '0:00:52.7',
#                                                                    'thumbnailId': '27c0faef-90a2-4d8c-a128-fd1bc05a388d'}]},
#                                                    {'id': 49,
#                                                     'instances': [{'adjustedEnd': '0:00:53.2333333',
#                                                                    'adjustedStart': '0:00:53.2',
#                                                                    'end': '0:00:53.2333333',
#                                                                    'start': '0:00:53.2',
#                                                                    'thumbnailId': 'd9f41245-80a1-4cc4-a126-2a384eea4f46'}]}],
#                                      'tags': ['ExtremeCloseUp', 'CenterFace']},
#                                     {'id': 34,
#                                      'instances': [{'adjustedEnd': '0:00:56.2',
#                                                     'adjustedStart': '0:00:55.0333333',
#                                                     'end': '0:00:56.2',
#                                                     'start': '0:00:55.0333333'}],
#                                      'keyFrames': [{'id': 50,
#                                                     'instances': [{'adjustedEnd': '0:00:55.1333333',
#                                                                    'adjustedStart': '0:00:55.1',
#                                                                    'end': '0:00:55.1333333',
#                                                                    'start': '0:00:55.1',
#                                                                    'thumbnailId': '82761c93-015f-4b8e-946c-0334d14a4e34'}]}],
#                                      'tags': ['ExtremeCloseUp', 'CenterFace']},
#                                     {'id': 35,
#                                      'instances': [{'adjustedEnd': '0:00:57.5666667',
#                                                     'adjustedStart': '0:00:56.2',
#                                                     'end': '0:00:57.5666667',
#                                                     'start': '0:00:56.2'}],
#                                      'keyFrames': [{'id': 51,
#                                                     'instances': [{'adjustedEnd': '0:00:56.5',
#                                                                    'adjustedStart': '0:00:56.4666667',
#                                                                    'end': '0:00:56.5',
#                                                                    'start': '0:00:56.4666667',
#                                                                    'thumbnailId': '37d52aee-d832-40fb-b6a0-205243d4b007'}]}],
#                                      'tags': ['CloseUp', 'CenterFace']},
#                                     {'id': 36,
#                                      'instances': [{'adjustedEnd': '0:00:58.7',
#                                                     'adjustedStart': '0:00:57.5666667',
#                                                     'end': '0:00:58.7',
#                                                     'start': '0:00:57.5666667'}],
#                                      'keyFrames': [{'id': 52,
#                                                     'instances': [{'adjustedEnd': '0:00:57.6666667',
#                                                                    'adjustedStart': '0:00:57.6333333',
#                                                                    'end': '0:00:57.6666667',
#                                                                    'start': '0:00:57.6333333',
#                                                                    'thumbnailId': '2cb5c1ec-a0a0-446a-bc47-da16ea27459b'}]}],
#                                      'tags': ['ExtremeCloseUp', 'CenterFace']},
#                                     {'id': 37,
#                                      'instances': [{'adjustedEnd': '0:00:59.8',
#                                                     'adjustedStart': '0:00:58.7',
#                                                     'end': '0:00:59.8',
#                                                     'start': '0:00:58.7'}],
#                                      'keyFrames': [{'id': 53,
#                                                     'instances': [{'adjustedEnd': '0:00:59',
#                                                                    'adjustedStart': '0:00:58.9666667',
#                                                                    'end': '0:00:59',
#                                                                    'start': '0:00:58.9666667',
#                                                                    'thumbnailId': '7ea7312e-c4f4-4034-b725-7c85f338892b'}]}],
#                                      'tags': ['CloseUp', 'CenterFace']}],
#                           'sourceLanguage': 'en-US',
#                           'sourceLanguages': ['en-US'],
#                           'speakers': [{'id': 1,
#                                         'instances': [{'adjustedEnd': '0:00:02.04',
#                                                        'adjustedStart': '0:00:01.96',
#                                                        'end': '0:00:02.04',
#                                                        'start': '0:00:01.96'}],
#                                         'name': 'Speaker #1'},
#                                        {'id': 2,
#                                         'instances': [{'adjustedEnd': '0:00:33.68',
#                                                        'adjustedStart': '0:00:33.6',
#                                                        'end': '0:00:33.68',
#                                                        'start': '0:00:33.6'}],
#                                         'name': 'Speaker #2'}],
#                           'statistics': {'correspondenceCount': 1,
#                                          'speakerLongestMonolog': {'1': 0,
#                                                                    '2': 0},
#                                          'speakerNumberOfFragments': {'1': 1,
#                                                                       '2': 1},
#                                          'speakerTalkToListenRatio': {'1': 0.5,
#                                                                       '2': 0.5},
#                                          'speakerWordCount': {'1': 1, '2': 1}},
#                           'textualContentModeration': {'bannedWordsCount': 0,
#                                                        'bannedWordsRatio': 0,
#                                                        'id': 0,
#                                                        'instances': []},
#                           'topics': [{'confidence': 0.5213,
#                                       'iabName': 'Education',
#                                       'id': 1,
#                                       'instances': [{'adjustedEnd': '0:00:33.68',
#                                                      'adjustedStart': '0:00:01.96',
#                                                      'end': '0:00:33.68',
#                                                      'start': '0:00:01.96'}],
#                                       'iptcName': 'science and technology',
#                                       'language': 'en-US',
#                                       'name': 'Technology',
#                                       'referenceId': 'Education/Technology',
#                                       'referenceType': 'VideoIndexer'}],
#                           'transcript': [{'confidence': 0.152,
#                                           'id': 1,
#                                           'instances': [{'adjustedEnd': '0:00:02.04',
#                                                          'adjustedStart': '0:00:01.96',
#                                                          'end': '0:00:02.04',
#                                                          'start': '0:00:01.96'}],
#                                           'language': 'en-US',
#                                           'speakerId': 1,
#                                           'text': 'I.'},
#                                          {'confidence': 0.208,
#                                           'id': 2,
#                                           'instances': [{'adjustedEnd': '0:00:33.68',
#                                                          'adjustedStart': '0:00:33.6',
#                                                          'end': '0:00:33.68',
#                                                          'start': '0:00:33.6'}],
#                                           'language': 'en-US',
#                                           'speakerId': 2,
#                                           'text': 'I.'}],
#                           'version': '1.0.0.0'},
#              'isAdult': False,
#              'language': 'en-US',
#              'languageAutoDetectMode': 'None',
#              'languages': ['en-US'],
#              'linguisticModelId': '00000000-0000-0000-0000-000000000000',
#              'logoGroupId': None,
#              'metadata': None,
#              'moderationState': 'OK',
#              'personModelId': '00000000-0000-0000-0000-000000000000',
#              'privacyMode': 'Private',
#              'processingProgress': '100%',
#              'publishedProxyUrl': None,
#              'publishedUrl': 'https://api.videoindexer.ai/internals/eastus/Accounts/f9e62e90-4040-4f12-aebd-1c3b703fc2b2/Videos/bca891963e/streaming-manifest/manifest.m3u8',
#              'reviewState': 'None',
#              'sourceLanguage': 'en-US',
#              'sourceLanguages': ['en-US'],
#              'state': 'Processed',
#              'streamingPreset': 'Default',
#              'thumbnailId': '395f3aa4-c185-4ce1-8568-7730f9c120c2',
#              'viewToken': 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.....MVNMfsRVbY5YIcCvyVvHFe6SvtQvoW8TS86UD8VKTHBo1IOk7SIQd9XpEBzgQ00IwHFKxK6lBcrL1ol387-_CDYhTwbB2Rg8lQcPHpSwPqYbixRfFrBGmKtW4_veYWGItKBb5BrBMFupgayiYq-KRBtXSCNz4f_Zr-bBMfg8piUQuIaGxhZft9nONRoLSzok7qoKiop5AicOIEVf175ThwTjhVEGOttP3LtiTHgA4LNe9CIo4CVZGN1vzgY_L5B6anZNRRq5TzY3pyBHPGqzqYPya0YOCOs8Vh5Ze_So8oFDwD7jitYof-MW73DZKKr5H5VsyxjhD3KH1iILvbiM8w',
#              'width': 720}],
#  'videosRanges': [{'range': {'end': '0:00:59.814603', 'start': '0:00:00'},
#                    'videoId': 'bca891963e'}]}

# %% [markdown]
# #### Sample 5 - Widgets API

# %%
client.get_insights_widgets_url_async(video_id, widget_type='Keywords')
client.get_player_widget_url_async(video_id)
# Out:
# Getting the insights widget URL for video bca891963e
# Got the insights widget URL: https://www.videoindexer.ai/embed/insights/f9e62e90-4040-4f12-aebd-1c3b703fc2b2/bca891963e/?location=eastus&widgets=Keywords&accessToken=eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.....SdpKPb7dq2OE9DDGDZTJLOvDSwaLOz7odpuzJIhHHysy_jSW0CZvix7qBOFz_aqBiigr_dkt3Sulin3aUxImSse35lxMtVhGWKnCKSBSbc3n1Hs7bUhYk-8Cj8aDxQC7MHxTCB4-M_pY5mhjZF7mxT6--bQRtNTkVvp6EakGNvIjTzfRqwzf0PXU3uo5tA1ZK-5LAZEsb9h7k268hxba7KaRfdI8_fwSzwbv9kbHZr_qbWhx6Osd6ih0L9ZkNqgtaqhPeT9bPZPxeD1rI4DFRcNQFAx3OU0NeeJ4NfyjbCnIaEWg5gTv6Ql9yXKKZNnXmSc-_vvtCxl203_T8d5DQw
# Getting the player widget URL for video bca891963e
# Got the player widget URL: https://www.videoindexer.ai/embed/player/f9e62e90-4040-4f12-aebd-1c3b703fc2b2/bca891963e/?location=eastus&accessToken=eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.....GpJu-sXeXT59mCYcOy-v_7jxJE7l2DmIxSDEtHMoieKEDUHizoxLthFY3wbXl1dEq5J6IvgHASV6a3PRDs6o9082-368NQblOwQ5I9XrDlbvdqV29KOpR6H3MgKAbmeKrevCYb_wMxPvXEtsOHr213PkEwPvhIXLLVpE7nWr0mvQzgD_CYbK4t5rrSNbkLsrHPycUSdMJ3n0FqKfg6rZ3Qvlmh7dXF04RiLJ3_hM2vrh6m882osPRIRA5N0P1SmDozwml3b6uQUkiKkeMMcx39ZvpbK7NmSRv9QDxZyxxEXsL8vgbbeEovfAwG3q6E5OFZMui6yeNUPnINNiYJhNZQ

# %% [markdown]
# #### Sample 6 - Prompt Content API

# %%
prompt_content = client.get_prompt_content(video_id)
pprint(prompt_content)
# Out:
# Prompt content generation for video_id='bca891963e' started...
# Prompt content is not ready yet. Waiting 5 seconds before checking again...
# Prompt content is not ready yet. Waiting 5 seconds before checking again...
# Prompt content is not ready yet. Waiting 5 seconds before checking again...
# Prompt content is not ready yet. Waiting 5 seconds before checking again...
# {'name': 'my-video-name',
#  'partition': None,
#  'sections': [{'content': '[Video title] my-video-name\n'
#                           '[Detected objects] necktie\n'
#                           '[Visual labels] human face, clothing, person, '
#                           'smile, man, t-shirt\n'
#                           '[OCR] MUNDO, DEPORTIVO, TEST A PEDRI, Pues te diría '
#                           'lbai, ¿Un videojuego?, FIFA, Pero ..., ¿Y por qué?, '
#                           'Porque soy muy malo, DE, ¿Un ídolo?, Iniesta, ¿Un '
#                           'ídolo fuera, del fútbol?, Spotify, Rafa Nadal, que '
#                           'no sea Ferran,, que ya sabemos, que Ferran, es tu '
#                           'amigo., ND, Eric Garcia, en una palabra, A ver, '
#                           'podría decirte, ídolo, por cómo, jugaba pero ..., '
#                           'como entrenador ..., Espectacular, Luis Enrique, te '
#                           'digo la frase de ..., TIVO, ¿El peor rival, que te '
#                           'has encontrado, de juego?, Mbappé, supongo, ¿Y el '
#                           'equipo, que te, has encontrado?, Mmmm ..., ¿Un '
#                           'estadio en el que, a parte del Camp Nou?, ¿Y uno en '
#                           'el que te ...?, El Sadar, Una app del móvil, '
#                           'Cuidado, a ver ..., Instagram ... bufff, No sé si '
#                           'Instagram, o Tik Tok, tu gol soñado?\n'
#                           '[Transcript] I.\n'
#                           'I.',
#                'end': '0:00:59.8',
#                'id': 0,
#                'start': '0:00:00'}]}
